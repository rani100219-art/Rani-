# %% [markdown]
# <a href="https://colab.research.google.com/github/rani100219-art/Rani-/blob/main/knn_iris_data_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.svm import SVC
iris = load_iris()
X,y = iris.data,iris.target

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
new_df=df.drop(['petal length (cm)','petal width (cm)'],axis=1)
new_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
X_train,X_test,y_train,y_test=train_test_split(new_df,y,test_size=0.2,random_state=21)

# %%
new_df['Euclidean_Distance'] = np.sqrt(new_df['sepal length (cm)']**2 + new_df['sepal width (cm)']**2)
new_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  Euclidean_Distance
# 0                5.1               3.5            6.185467
# 1                4.9               3.0            5.745433
# 2                4.7               3.2            5.685948
# 3                4.6               3.1            5.547071
# 4                5.0               3.6            6.161169

# %%
from sklearn.model_selection import KFold
kf=KFold(n_splits=5)
kf
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %%
X_train,X_test,y_train,y_test=train_test_split(new_df,y,test_size=0.2,random_state=21)

knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
accuracy_score = knn.score(X_test,y_test)
print(accuracy_score)
# Out:
# 0.7333333333333333

# %%
plt.plot(new_df['sepal length (cm)'],new_df['sepal width (cm)'])
